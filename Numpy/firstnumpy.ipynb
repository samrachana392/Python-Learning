# %% [markdown]
# # Welcome to numpy tutorial

# %%
import numpy as np

# %%
myarr=np.array([1,2,3,4])

# %%
print(myarr)
# Out:
# [1 2 3 4]

# %%
myarr
# Out:
# array([1, 2, 3, 4])

# %%
myarr[1]
# Out:
# np.int64(2)

# %%
myarr.shape
# Out:
# (4,)

# %%
arr=np.array([1,2,3], np.int8)

# %%
arr
# Out:
# array([1, 2, 3], dtype=int8)

# %%
arr[0]
# Out:
# np.int8(1)

# %%
arr=np.array([[6,9,3,0]], np.int64)

# %%
arr.shape # output means it has 1 row and 4 columns
# Out:
# (1, 4)

# %%
arr[0,2] #row=2 and colmn = 2 element
# Out:
# np.int64(3)

# %%
arr.dtype
# Out:
# dtype('int64')
