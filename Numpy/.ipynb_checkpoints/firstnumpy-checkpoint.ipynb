# %%
import numpy as np

# %%
print("hello world")
# Out:
# hello world

# %%
print(7)
# Out:
# 7

# %% [raw]
# i=45

# %%
print(8)
# Out:
# 8

# %%
i=45

# %%
i=45

# %%
print(i)
# Out:
# 45

# %%
i
# Out:
# 45

# %%
i=45
